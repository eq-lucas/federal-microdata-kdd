# %%
import sys
import pandas as pd
from src.staging import staging_fies, staging_inep
from src.transform_layer_1 import transform_inscritos, transform_ofertas, transform_inep, verificar_colunas_inep
from src.transform_layer_2 import tratar_nans_cine_inscritos, tratar_nans_cine_ofertas
from src.trasnform_layer_3 import processar_modalidades_e_peneira
from src.load import load_inscritos,load_ofertas,auditoria_inscritos_carregados,auditoria_ofertas_carregadas,exportar_para_sqlite
from src.analise_001 import gerar_dataset_candidatos_unicos_por_Prioridade_inicial
from src.analise_002 import eda_gerar_dataset_com_varias_analises
from src.analise_003 import eda_gerar_funil_de_selecao_6_etapas
from src.analise_004 import analise_fuga_cerebros_de_regioes
from src.analise_005 import verificar_qtde_inscritos_por_ano_e_semestre_nacional_e_regional
from src.analise_006 import gerar_dataset_e_grafico_heatmap_quem_sao_os_inscritos_contratados
from src.analise_007 import orquestrador_inicial_inscritos, orquestrador_ja_rodado_inscritos
from src.analise_008 import orquestrador_inicial_candidatos, orquestrador_ja_rodado_candidatos
from src.analise_009 import orquestrador_inicial_inscritos_nove, orquestrador_ja_rodado_inscritos_nove
from src.analise_009_1 import orquestrador_inicial_inscritos_nove_um, orquestrador_ja_rodado_inscritos_nove_um
from src.analise_010 import orquestrador_inicial_inscritos_dez, orquestrador_ja_rodado_inscritos_dez





comando = 'analise'
etapa = '9_1'

# --- CAMADA: STAGING ---
if comando == "staging":
    staging_fies()
    staging_inep()

# --- CAMADA: TRANSFORM ---
elif comando == "transform":

    if etapa == "1":
        transform_inep()
    elif etapa == "2":
        transform_inscritos()
    elif etapa == "3":
        transform_ofertas()
    elif etapa == "4":
        verificar_colunas_inep()
    elif etapa == "5":
        tratar_nans_cine_inscritos()
    elif etapa == "6":
        tratar_nans_cine_ofertas()
    elif etapa == "7":
        processar_modalidades_e_peneira()
    elif etapa == "all":
        transform_inep()
        transform_inscritos()
        transform_ofertas()
        verificar_colunas_inep()
        tratar_nans_cine_inscritos()
        tratar_nans_cine_ofertas()
        processar_modalidades_e_peneira()

elif comando == "load":

    load_inscritos()
    load_ofertas()
    auditoria_inscritos_carregados()
    auditoria_ofertas_carregadas()
    exportar_para_sqlite()

elif comando == 'analise':

    if etapa == "1":
        gerar_dataset_candidatos_unicos_por_Prioridade_inicial()

    elif etapa == "2":
        eda_gerar_dataset_com_varias_analises()

    elif etapa == "3":
        eda_gerar_funil_de_selecao_6_etapas()

    elif etapa == "4":
        analise_fuga_cerebros_de_regioes()

    elif etapa == "5":
        verificar_qtde_inscritos_por_ano_e_semestre_nacional_e_regional()

    elif etapa == "6":
        gerar_dataset_e_grafico_heatmap_quem_sao_os_inscritos_contratados()

    elif etapa == "7":
        orquestrador_inicial_inscritos()
    
    elif etapa == "7.1":
        orquestrador_ja_rodado_inscritos()

    elif etapa == "8":
        orquestrador_inicial_candidatos()
    
    elif etapa == "8.1":
        orquestrador_ja_rodado_candidatos()

    elif etapa == "9":
        orquestrador_inicial_inscritos_nove()
    
    elif etapa == "9.1":
        orquestrador_ja_rodado_inscritos_nove()

    elif etapa == "9_1":
        orquestrador_inicial_inscritos_nove_um()
    
    elif etapa == "9_1.1":
        orquestrador_ja_rodado_inscritos_nove_um()

    elif etapa == "10":
        orquestrador_inicial_inscritos_dez()
    
    elif etapa == "10.1":
        orquestrador_ja_rodado_inscritos_dez()
# Out:
# total de linhas de apenas 2019(1 e 2 semestre):  (1507420, 69)
# total de linhas de apenas 2020 e 2021 (1 e 2 semestre):  (689814, 69)
# ------------------------------------------------------------
# qtde de inscritos apenas de 2019 (1 e 2 semestre)
#                            situacao_fies  qtde_inscritos
# 0                             CONTRATADA          104114
# 1                   INSCRIÇÃO POSTERGADA              46
# 2                        LISTA DE ESPERA          541623
# 3                         NÃO CONTRATADO          711496
# 4                   OPÇÃO NÃO CONTRATADA           87919
# 5  PARTICIPACAO CANCELADA PELO CANDIDATO           59803
# 6                        PRÉ-SELECIONADO             211
# 7                    REJEITADA PELA CPSA            2208
# ------------------------------------------------------------
# qtde de inscritos apenas de 2020 e 2021 (1 e 2 semestre)
#                            situacao_fies  qtde_inscritos
# 0                             CONTRATADA           56255
# 1                   INSCRIÇÃO POSTERGADA            2278
# 2                        LISTA DE ESPERA          199075
# 3                         NÃO CONTRATADO          313108
# 4                   OPÇÃO NÃO CONTRATADA           51550
# 5  PARTICIPACAO CANCELADA PELO CANDIDATO           51399
# 6                        PRÉ-SELECIONADO           12712
# 7                    REJEITADA PELA CPSA            3437
# --- Quantidade de NaNs por coluna ---
# renda_per_capita                                                                                                             0
# gap                                                                                                                          1
# idade                                                                                                                        0
# concluiu_curso_superior_SIM                                                                                                  0
# conceito_curso_gp_4                                                                                                          0
# conceito_curso_gp_5                                                                                                          0
# conceito_curso_gp_AUTORIZADO                                                                                                 0
# subarea_conhecimento_AGRONEGÓCIO, AGROINDÚSTRIA E CURSOS RELACIONADOS                                                        0
# subarea_conhecimento_AGRONOMIA, ZOOTECNIA, ENGENHARIA FLORESTAL E CURSOS RELACIONADOS                                        0
# subarea_conhecimento_ARTES, CIÊNCIAS SOCIAIS E CURSOS RELACIONADOS                                                           0
# subarea_conhecimento_BIOLOGIA (LIC), MATEMÁTICA (LIC), LETRAS-PORTUGUÊS E CURSOS RELACIONADOS                                0
# subarea_conhecimento_CIÊNCIA DA COMPUTAÇÃO E SISTEMAS DE INFORMAÇÃO E CURSOS RELACIONADOS                                    0
# subarea_conhecimento_CIÊNCIAS AERONÁUTICAS E CURSOS RELACIONADOS                                                             0
# subarea_conhecimento_CIÊNCIAS BIOLÓGICAS (BEL), BIOMEDICINA, BIOTECNOLOGIA E CURSOS RELACIONADOS                             0
# subarea_conhecimento_CIÊNCIAS SOCIAIS, POLÍTICAS, ECONÔMICAS E CONTÁBEIS, PSICOLOGIA E SECRETARIADO                          0
# subarea_conhecimento_COMUNICAÇÃO SOCIAL, JORNALISMO, PUBLICIDADE, MARKETING E CURSOS RELACIONADOS                            0
# subarea_conhecimento_COMUNICAÇÃO, DESIGN, AUDIO VISUAL E CURSOS RELACIONADOS                                                 0
# subarea_conhecimento_DANÇA, TEOLOGIA, MÍDIAS SOCIAIS, DESIGN DE INTERIORES E CURSOS RELACIONADOS                             0
# subarea_conhecimento_DIREITO, COMÉRCIO EXTERIOR, BIBLIOTECONOMIA E CURSOS RELACIONADOS                                       0
# subarea_conhecimento_ENFERMAGEM, FISIOTERAPIA, FARMÁCIA, NUTRIÇÃO E CURSOS RELACIONADOS                                      0
# subarea_conhecimento_ENGENHARIA CIVIL E AMBIENTAL, ARQUITETURA E CURSOS RELACIONADOS                                         0
# subarea_conhecimento_ENGENHARIA DE PRODUÇÃO, DE MATERIAIS E CURSOS RELACIONADOS                                              0
# subarea_conhecimento_ENGENHARIA DE SEGURANÇA DO TRABALHO, GESTÃO EM SAÚDE E CURSOS RELACIONADOS                              0
# subarea_conhecimento_ENGENHARIA ELÉTRICA, ELETRÔNICA, DA COMPUTAÇÃO E CURSOS RELACIONADOS                                    0
# subarea_conhecimento_ENGENHARIA MECÂNICA, AERONÁUTICA, NAVAL E CURSOS RELACIONADOS                                           0
# subarea_conhecimento_ENGENHARIA QUÍMICA, DE ALIMENTOS, DE PETRÓLEO E CURSOS RELACIONADOS                                     0
# subarea_conhecimento_ESTÉTICA E COSMÉTICA, GESTÃO DO ESPORTE E CURSOS RELACIONADOS                                           0
# subarea_conhecimento_FÍSICA (BEL), QUÍMICA (BEL), MATEMÁTICA (BEL), GEOGRAFIA (BEL) E CURSOS RELACIONADOS                    0
# subarea_conhecimento_GESTÃO EDUCACIONAL, PROCESSOS ESCOLARES E CURSOS RELACIONADOS                                           0
# subarea_conhecimento_HISTÓRIA (LIC), GEOGRAFIA (LIC), EDUCAÇÃO FÍSICA (LIC) E CURSOS RELACIONADOS                            0
# subarea_conhecimento_HOTELARIA E TURISMO, GASTRONOMIA E CURSOS RELACIONADOS                                                  0
# subarea_conhecimento_LETRAS - IDIOMAS, FÍSICA (LIC), QUÍMICA (LIC) E CURSOS RELACIONADOS                                     0
# subarea_conhecimento_MEDICINA                                                                                                0
# subarea_conhecimento_MEDICINA VETERINÁRIA                                                                                    0
# subarea_conhecimento_MODA, DESENHO INDUSTRIAL, MUSEOLOGIA, CINEMA E CURSOS RELACIONADOS                                      0
# subarea_conhecimento_MÚSICA, FOTOGRAFIA, PRODUÇÃO MULTIMÍDIA E CURSOS RELACIONADOS                                           0
# subarea_conhecimento_ODONTOLOGIA, QUIROPRAXIA, FÍSICA MÉDICA E NATUROLOGIA                                                   0
# subarea_conhecimento_PEDAGOGIA                                                                                               0
# subarea_conhecimento_SERVIÇO SOCIAL, FONOAUDIOLOGIA, TERAPIA OCUPACIONAL E CURSOS RELACIONADOS                               0
# subarea_conhecimento_TRADUÇÃO E INTERPRETAÇÃO, ARQUEOLOGIA, RÁDIO, TV E INTERNET E CURSOS RELACIONADOS                       0
# regiao_morar_Nordeste                                                                                                        0
# regiao_morar_Norte                                                                                                           0
# regiao_morar_Sudeste                                                                                                         0
# regiao_morar_Sul                                                                                                             0
# natureza_juridica_mantenedora_PESSOA JURÍDICA DE DIREITO PRIVADO - COM FINS LUCRATIVOS - SOCIEDADE CIVIL                     0
# natureza_juridica_mantenedora_PESSOA JURÍDICA DE DIREITO PRIVADO - COM FINS LUCRATIVOS - SOCIEDADE MERCANTIL OU COMERCIAL    0
# natureza_juridica_mantenedora_PESSOA JURÍDICA DE DIREITO PRIVADO - SEM FINS LUCRATIVOS - ASSOCIAÇÃO DE UTILIDADE PÚBLICA     0
# natureza_juridica_mantenedora_PESSOA JURÍDICA DE DIREITO PRIVADO - SEM FINS LUCRATIVOS - FUNDAÇÃO                            0
# natureza_juridica_mantenedora_PESSOA JURÍDICA DE DIREITO PRIVADO - SEM FINS LUCRATIVOS - SOCIEDADE                           0
# natureza_juridica_mantenedora_PESSOA JURÍDICA DE DIREITO PÚBLICO - MUNICIPAL                                                 0
# natureza_juridica_mantenedora_PRIVADA COM FINS LUCRATIVOS                                                                    0
# natureza_juridica_mantenedora_PRIVADA SEM FINS LUCRATIVOS                                                                    0
# etnia_cor_BRANCA                                                                                                             0
# etnia_cor_INDÍGENA                                                                                                           0
# etnia_cor_PARDA                                                                                                              0
# etnia_cor_PRETA                                                                                                              0
# turno_MATUTINO                                                                                                               0
# turno_NOTURNO                                                                                                                0
# turno_VESPERTINO                                                                                                             0
# ensino_medio_escola_publica_PARCIAL                                                                                          0
# ensino_medio_escola_publica_SIM                                                                                              0
# dtype: int64
# coluna x linha do X com NaN inclusos: (815609, 61)
# coluna x linha do X sem NaN inclusos: (815609, 61)
# ------------------------------------------------------------
# Arquivos da ABT salvos com sucesso em:
# /home/eq_lucas/Documents/projetos/kdd-pipeline-microdata-fies/data/05_processed/analise_009_1
# Registros de Treino: 815,609
# Registros de Teste: 369,363
# /home/eq_lucas/Documents/projetos/kdd-pipeline-microdata-fies/venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/eq_lucas/Documents/projetos/kdd-pipeline-microdata-fies/venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# --- Treinamento Concluído ---
# Modelo salvo em: /home/eq_lucas/Documents/projetos/kdd-pipeline-microdata-fies/reports/models/analise_009_1_modelo_fies_logistica.pkl
# 815,609 registros processados.
# Top 20 variáveis mais importantes:
#                                              Variável  Coeficiente  \
# 18  subarea_conhecimento_DIREITO, COMÉRCIO EXTERIO...     0.441164
# 0                                    renda_per_capita    -0.413833
# 19  subarea_conhecimento_ENFERMAGEM, FISIOTERAPIA,...     0.411941
# 36  subarea_conhecimento_ODONTOLOGIA, QUIROPRAXIA,...     0.390719
# 51  natureza_juridica_mantenedora_PRIVADA SEM FINS...     0.304740
# 1                                                 gap     0.299492
# 50  natureza_juridica_mantenedora_PRIVADA COM FINS...     0.286869
# 20  subarea_conhecimento_ENGENHARIA CIVIL E AMBIEN...     0.281701
# 33          subarea_conhecimento_MEDICINA VETERINÁRIA     0.250726
# 14  subarea_conhecimento_CIÊNCIAS SOCIAIS, POLÍTIC...     0.250305
# 56                                     turno_MATUTINO    -0.221841
# 32                      subarea_conhecimento_MEDICINA     0.209293
# 46  natureza_juridica_mantenedora_PESSOA JURÍDICA ...     0.208269
# 5                                 conceito_curso_gp_5     0.174829
# 60                    ensino_medio_escola_publica_SIM    -0.165019
# 13  subarea_conhecimento_CIÊNCIAS BIOLÓGICAS (BEL)...     0.164191
# 23  subarea_conhecimento_ENGENHARIA ELÉTRICA, ELET...     0.145004
# 8   subarea_conhecimento_AGRONOMIA, ZOOTECNIA, ENG...     0.133311
# 24  subarea_conhecimento_ENGENHARIA MECÂNICA, AERO...     0.123302
# 2                                               idade    -0.112401
#
#     Impacto_Absoluto
# 18          0.441164
# 0           0.413833
# 19          0.411941
# 36          0.390719
# 51          0.304740
# 1           0.299492
# 50          0.286869
# 20          0.281701
# 33          0.250726
# 14          0.250305
# 56          0.221841
# 32          0.209293
# 46          0.208269
# 5           0.174829
# 60          0.165019
# 13          0.164191
# 23          0.145004
# 8           0.133311
# 24          0.123302
# 2           0.112401
# ROC-AUC: 0.6958
# Acurácia (threshold ótimo): 0.6423
# Threshold ótimo: 0.5034
