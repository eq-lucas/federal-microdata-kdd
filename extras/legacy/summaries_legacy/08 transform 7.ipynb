# %%
import sys
import pandas as pd
from src.staging import staging_fies, staging_inep
from src.transform_layer_1 import transform_inscritos, transform_ofertas, transform_inep, verificar_colunas_inep
from src.transform_layer_2 import tratar_nans_cine_inscritos, tratar_nans_cine_ofertas
from src.trasnform_layer_3 import processar_modalidades_e_peneira
from src.load import load_inscritos,load_ofertas,auditoria_inscritos_carregados,auditoria_ofertas_carregadas,exportar_para_sqlite
    
comando = 'transform'
etapa = '7'

# --- CAMADA: STAGING ---
if comando == "staging":
    staging_fies()
    staging_inep()

# --- CAMADA: TRANSFORM ---
elif comando == "transform":

    if etapa == "1":
        transform_inep()
    elif etapa == "2":
        transform_inscritos()
    elif etapa == "3":
        transform_ofertas()
    elif etapa == "4":
        verificar_colunas_inep()
    elif etapa == "5":
        tratar_nans_cine_inscritos()
    elif etapa == "6":
        tratar_nans_cine_ofertas()
    elif etapa == "7":
        processar_modalidades_e_peneira()
    elif etapa == "all":
        transform_inep()
        transform_inscritos()
        transform_ofertas()
        verificar_colunas_inep()
        tratar_nans_cine_inscritos()
        tratar_nans_cine_ofertas()
        processar_modalidades_e_peneira()

elif comando == "load":

    load_inscritos()
    load_ofertas()
    auditoria_inscritos_carregados()
    auditoria_ofertas_carregadas()
    exportar_para_sqlite()
# Out:
# ================================================================================
# 🧠 INICIANDO LAYER 3: CLASSIFICAÇÃO DE MODALIDADES E PENEIRA SOCIOECONÔMICA
# ================================================================================
# [*] Carregando datasets da Layer 2...
#
# ------------------------------------------------------------
# 📊 1. AUDITORIA VOLUMÉTRICA: STAGING vs LAYER 2
# ------------------------------------------------------------
# [*] Varrendo pasta 02_staging para somar volume original de inscrições...
#   -> Total de inscrições no Staging (Pós-deduplicação): 2197234
#   -> Total de inscrições na Layer 2 (Atual)           : 2197234
#   ✅ SUCESSO: 100% de integridade volumétrica mantida. Nenhum aluno perdido.
#
# ------------------------------------------------------------
# 💰 2. APLICAÇÃO DAS REGRAS DE NEGÓCIO (CORTES DE RENDA E REGIÃO)
# ------------------------------------------------------------
#   [Ano 2019] Salário Mínimo: R$  998.00 | Limite Mod I (3 SM): R$ 2994.00 | Limite Mod II/III (5 SM): R$ 4990.00
#   [Ano 2020] Salário Mínimo: R$ 1045.00 | Limite Mod I (3 SM): R$ 3135.00 | Limite Mod II/III (5 SM): R$ 5225.00
#   [Ano 2021] Salário Mínimo: R$ 1100.00 | Limite Mod I (3 SM): R$ 3300.00 | Limite Mod II/III (5 SM): R$ 5500.00
#
# [*] Executando a Peneira Socioeconômica Inicial...
#   -> Aprovados na Modalidade I   (Renda <= 3SM)       : 2184798
#   -> Aprovados na Modalidade II  (3-5SM, N/NE/CO)     : 6684
#   -> Aprovados na Modalidade III (3-5SM, Sul/Sudeste) : 5684
#   -> Eliminados PRELIMINARMENTE  (Renda Alta ou Nula) : 68
#
# ------------------------------------------------------------
# 🔄 3. VALIDAÇÃO DE CONTRADIÇÃO DO MEC (P-FIES)
# ------------------------------------------------------------
# [*] Verificando se os candidatos da Modalidade III aplicaram para vagas que realmente aceitam P-FIES...
#   -> Candidatos que passaram na renda Mod III         : 5684
#   -> Ofertas de faculdades que rejeitavam P-FIES      : 267 (Eliminados do sistema)
#   -> Candidatos DEFINITIVOS na Modalidade III         : 5417
#
# ------------------------------------------------------------
# 📊 4. RESUMO FORENSE DA LAYER 3 (MATRIZ FINAL)
# ------------------------------------------------------------
# modalidade_fies                  Modalidade I  Modalidade II  Modalidade III (P-FIES)  eliminado
# ano_processo_seletivo_inscricao
# 2019                                   959662           4615                     3651        119
# 2020                                   744995           1993                     1766        121
# 2021                                   480141             76                        0         95
#
# [*] Salvando dataset final e injetando na próxima camada...
# ✅ LAYER 3 CONCLUÍDA! Salvo em: fies_inscritos_com_modalidade_final.parquet
# ================================================================================
