# %%
import sys
import pandas as pd
from src.staging import staging_fies, staging_inep
from src.transform_layer_1 import transform_inscritos, transform_ofertas, transform_inep, verificar_colunas_inep
from src.transform_layer_2 import tratar_nans_cine_inscritos, tratar_nans_cine_ofertas
from src.trasnform_layer_3 import processar_modalidades_e_peneira
from src.load import load_inscritos,load_ofertas,auditoria_inscritos_carregados,auditoria_ofertas_carregadas,exportar_para_sqlite
    
comando = 'load'
etapa = '7'

# --- CAMADA: STAGING ---
if comando == "staging":
    staging_fies()
    staging_inep()

# --- CAMADA: TRANSFORM ---
elif comando == "transform":

    if etapa == "1":
        transform_inep()
    elif etapa == "2":
        transform_inscritos()
    elif etapa == "3":
        transform_ofertas()
    elif etapa == "4":
        verificar_colunas_inep()
    elif etapa == "5":
        tratar_nans_cine_inscritos()
    elif etapa == "6":
        tratar_nans_cine_ofertas()
    elif etapa == "7":
        processar_modalidades_e_peneira()
    elif etapa == "all":
        transform_inep()
        transform_inscritos()
        transform_ofertas()
        verificar_colunas_inep()
        tratar_nans_cine_inscritos()
        tratar_nans_cine_ofertas()
        processar_modalidades_e_peneira()

elif comando == "load":

    load_inscritos()
    load_ofertas()
    auditoria_inscritos_carregados()
    auditoria_ofertas_carregadas()
    exportar_para_sqlite()
# Out:
# ============================================================
# 📦 INICIANDO LAYER 4 (LOAD): PADRONIZAÇÃO FINAL - INSCRITOS
# ============================================================
# [*] Lendo dataset pós-peneira: fies_inscritos_com_modalidade_final.parquet
# [*] Renomeando colunas para o padrão do Banco de Dados...
# [*] Tratando strings de UF e aplicando Fallback Inteligente (IES -> Local de Oferta)...
# [*] Garantindo que Ano e Semestre sejam números Inteiros...
# [*] Salvando versão final (Parquet) em: database/...
# [*] Salvando versão final (Parquet) em: database/...
#
# [OK] Dataset de Inscritos PRONTO PARA ANÁLISE.
# Colunas Finais: 67
# ============================================================
#
# ============================================================
# 📦 INICIANDO LAYER 4 (LOAD): PADRONIZAÇÃO FINAL - OFERTAS
# ============================================================
# [*] Lendo dataset de ofertas: fies_ofertas_unificado_corrigido.parquet
# [*] Renomeando colunas...
# [*] Tratando string de UF e criando nova coluna 'regiao_ies'...
#    [AVISO] 1 ofertas tinham UF inválida ou faltante.
# [*] Removendo linhas fantasmas (sem ano) e forçando Inteiros...
# [*] Salvando versão final (Parquet) em: database/...
#
# [OK] Fase LOAD concluída! Dataset de Ofertas PRONTO PARA ANÁLISE.
# Colunas Finais: 70
# ============================================================
#
# ==========================================================================================
# 🕵️  AUDITORIA FORENSE E RASTREABILIDADE PROFUNDA: INSCRITOS
# ==========================================================================================
# [*] Carregando as 3 camadas de dados (Raw, Staging, Final) para acareação...
#
# ------------------------------------------------------------
# 1. AUDITORIA VOLUMÉTRICA E PERDA DE DADOS
# ------------------------------------------------------------
# Linhas em RAW     (Bruto c/ duplicatas) : 2217921
# Linhas em STAGING (Deduplicadas)        : 2197234
# Linhas em FINAL   (Carregadas no BD)    : 2197234
# -> Integridade de PKs únicas: RAW (2197234) vs FINAL (2197234)
#    ✅ MATEMATICAMENTE PERFEITO: Nenhuma inscrição real foi perdida no pipeline.
#
# ------------------------------------------------------------
# 2. TESTE DE RASTREABILIDADE DE VALORES (RAW vs FINAL)
# ------------------------------------------------------------
# Sorteando candidato aleatório para acareação:
# ID: 351069897 | Opção: 2
#
#   Sexo               | RAW: F               | FINAL: F               -> ✅ IGUAL
#   Data de Nasc.      | RAW: 16/05/2003      | FINAL: 16/05/2003      -> ✅ IGUAL
#   UF Residência      | RAW: DF              | FINAL: DF              -> ✅ IGUAL
#   Renda Per Capita   | RAW: 424.0           | FINAL: 424.0           -> ✅ IGUAL
#   Nota Redação       | RAW: 560.0           | FINAL: 560.0           -> ✅ IGUAL
#   Média ENEM         | RAW: 508.76          | FINAL: 508.76          -> ✅ IGUAL
#   Nome do Curso      | RAW: FISIOTERAPIA    | FINAL: FISIOTERAPIA    -> ✅ IGUAL
#   Turno              | RAW: MATUTINO        | FINAL: MATUTINO        -> ✅ IGUAL
#
# ------------------------------------------------------------
# 3. ANÁLISE PROFUNDA DE ÁREAS CINE (NaNs RESTANTES)
# ------------------------------------------------------------
# -> Total de inscrições com CÓDIGO CINE = NaN: 25361
#    (Isso afeta 195 nomes de cursos únicos. Ex: ['GESTÃO AMBIENTAL' 'FARMÁCIA' 'LETRAS - PORTUGUÊS E INGLÊS'])
#
# -> Total de inscrições TOTALMENTE ÓRFÃOS (Cód + Nome CINE ausentes): 0
#    ✅ Nenhuma inscrição está com o CINE totalmente em branco.
# ==========================================================================================
#
#
# ==========================================================================================
# 🕵️  AUDITORIA FORENSE E RASTREABILIDADE PROFUNDA: OFERTAS
# ==========================================================================================
# [*] Carregando as 3 camadas de dados (Raw, Staging, Final) para acareação...
#
# ------------------------------------------------------------
# 1. AUDITORIA VOLUMÉTRICA E PERDA DE DADOS
# ------------------------------------------------------------
# Linhas em RAW     (Bruto original)      : 168238
# Linhas em RAW     (Sem linha fantasma)  : 143622
# Linhas em STAGING (Deduplicadas)        : 143623
# Linhas em FINAL   (Carregadas no BD)    : 143622
# -> Integridade de PKs únicas: RAW (42304) vs FINAL (42304)
#    ✅ MATEMATICAMENTE PERFEITO: Nenhuma oferta real foi perdida.
#
# ------------------------------------------------------------
# 2. TESTE DE RASTREABILIDADE DE VALORES (RAW vs FINAL)
# ------------------------------------------------------------
# Sorteando oferta aleatória para acareação:
# IES: 1390.0 | Curso: 1332806.0 | Turno: VESPERTINO
#
#   Nome IES           | RAW: Faculdade Alenc | FINAL: FACULDADE ALENC -> ✅ IGUAL
#   UF IES             | RAW: CE              | FINAL: CE              -> ✅ IGUAL
#   Nome do Curso      | RAW: FISIOTERAPIA    | FINAL: FISIOTERAPIA    -> ✅ IGUAL
#   Turno              | RAW: VESPERTINO      | FINAL: VESPERTINO      -> ✅ IGUAL
#   Vagas Mec          | RAW: 100.0           | FINAL: 100.0           -> ✅ IGUAL
#   Vagas FIES         | RAW: 40.0            | FINAL: 40.0            -> ✅ IGUAL
#   Participa P-FIES   | RAW: nan             | FINAL: SIM             -> ⚠️ DIVERGE
#   Valor Bruto        | RAW: N/A             | FINAL: 87749.24        -> ⚠️ DIVERGE
#
# ------------------------------------------------------------
# 3. ANÁLISE PROFUNDA DE ÁREAS CINE (NaNs RESTANTES)
# ------------------------------------------------------------
# -> Total de vagas com CÓDIGO CINE = NaN: 6119
#    (Afeta 216 cursos únicos. Ex: ['FORMAÇÃO PEDAGÓGICA PARA PORTADORES DE ENSINO SUPERIOR'
#  'SEGURANÇA DA INFORMAÇÃO' 'COMUNICAÇÃO INSTITUCIONAL'])
#
# -> Total de ofertas TOTALMENTE ÓRFÃS (Cód + Nome CINE ausentes): 5
#    [!] Estes cursos precisam de inclusão no dicionário de Ofertas (Layer 2):
# nome_curso
# NORMAL  SUPERIOR                                                  3
# COMUNICAÇÃO SOCIAL COM HABILITAÇÃO EM PUBLICIDADE E PROPAGANDA    2
# Name: count, dtype: int64
# ==========================================================================================
#
#
# ================================================================================
# 💾 INICIANDO EXPORTAÇÃO PARA BANCO DE DADOS SQLITE
# ================================================================================
# [*] Lendo Parquet de Inscritos e criando tabela 'inscritos' no BD...
#    ✅ Tabela 'inscritos' criada/atualizada com sucesso!
#
# [*] Lendo Parquet de Ofertas e criando tabela 'ofertas' no BD...
#    ✅ Tabela 'ofertas' criada/atualizada com sucesso!
#
# [OK] BANCO DE DADOS PRONTO! Caminho: /home/eq_lucas/Documents/projetos/kdd-pipeline-microdata-fies/data/04_load/database/fies_database.db
# ================================================================================
