# %%
import sys
import pandas as pd
from src.staging import staging_fies, staging_inep
from src.transform_layer_1 import transform_inscritos, transform_ofertas, transform_inep, verificar_colunas_inep
from src.transform_layer_2 import tratar_nans_cine_inscritos, tratar_nans_cine_ofertas
from src.trasnform_layer_3 import processar_modalidades_e_peneira
from src.load import load_inscritos,load_ofertas,auditoria_inscritos_carregados,auditoria_ofertas_carregadas,exportar_para_sqlite
    
comando = 'transform'
etapa = '5'

# --- CAMADA: STAGING ---
if comando == "staging":
    staging_fies()
    staging_inep()

# --- CAMADA: TRANSFORM ---
elif comando == "transform":

    if etapa == "1":
        transform_inep()
    elif etapa == "2":
        transform_inscritos()
    elif etapa == "3":
        transform_ofertas()
    elif etapa == "4":
        verificar_colunas_inep()
    elif etapa == "5":
        tratar_nans_cine_inscritos()
    elif etapa == "6":
        tratar_nans_cine_ofertas()
    elif etapa == "7":
        processar_modalidades_e_peneira()
    elif etapa == "all":
        transform_inep()
        transform_inscritos()
        transform_ofertas()
        verificar_colunas_inep()
        tratar_nans_cine_inscritos()
        tratar_nans_cine_ofertas()
        processar_modalidades_e_peneira()

elif comando == "load":

    load_inscritos()
    load_ofertas()
    auditoria_inscritos_carregados()
    auditoria_ofertas_carregadas()
    exportar_para_sqlite()
# Out:
# ============================================================
# INICIANDO LAYER 2: TRATAMENTO DE NaNs CINE - INSCRITOS
# ============================================================
# [*] Lendo arquivo unificado: fies_inscritos_unificado.parquet...
#
# [*] ETAPA A: Extraindo dicionário de cursos válidos...
#   -> Salvo: dataset_auxiliar_curso_area_inscritos.csv (362 cursos únicos sem NaN)
#
# [*] ETAPA B: Analisando cursos com CINE não mapeado (NaNs)...
#   -> Total de NaNs encontrados ANTES da correção: 25361
#   -> Lista de cursos problemáticos salva em: analise_nomes_nan_inscricao.csv
#
# [*] ETAPA C: Aplicando correções do dicionário manual...
#   -> Total de NaNs DEPOIS da correção: 0
#   -> Total de NaNs resolvidos: 25361
#
# [*] ETAPA D: Salvando o Dataset Unificado Corrigido...
#   -> Arquivo final salvo com sucesso em: fies_inscritos_unificado_corrigido.parquet
#
# ============================================================
# ✅ LAYER 2 CONCLUÍDA
# ============================================================
#
# ================================================================================
# 🎯 AUDITORIA PÓS-CORREÇÃO (LAYER 2): FIES INSCRITOS
# ================================================================================
#
# 📊 Contagem Global de Valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             1049914
# Negócios, administração e direito                              538713
# Engenharia, produção e construção                              186285
# Ciências sociais, comunicação e informação                     158921
# Agricultura, silvicultura, pesca e veterinária                  82811
# Educação                                                        68044
# Computação e Tecnologias da Informação e Comunicação (TIC)      54803
# Serviços                                                        31499
# Artes e humanidades                                             19009
# Ciências naturais, matemática e estatística                      7235
# Name: count, dtype: int64
#
# ----------------------------------------
# ✅ RESUMO DE INTEGRIDADE (FINAL)
# ----------------------------------------
# Total de Inscritos Processados : 2197234
# Total de NaNs (Não Mapeados)    : 0
# Taxa de Perda Residual          : 0.00%
# ================================================================================
