# %%
import sys
import pandas as pd
from src.staging import staging_fies, staging_inep
from src.transform_layer_1 import transform_inscritos, transform_ofertas, transform_inep, verificar_colunas_inep
from src.transform_layer_2 import tratar_nans_cine_inscritos, tratar_nans_cine_ofertas
from src.trasnform_layer_3 import processar_modalidades_e_peneira
from src.load import load_inscritos,load_ofertas,auditoria_inscritos_carregados,auditoria_ofertas_carregadas,exportar_para_sqlite
    
comando = 'transform'
etapa = '1'

# --- CAMADA: STAGING ---
if comando == "staging":
    staging_fies()
    staging_inep()

# --- CAMADA: TRANSFORM ---
elif comando == "transform":

    if etapa == "1":
        transform_inep()
    elif etapa == "2":
        transform_inscritos()
    elif etapa == "3":
        transform_ofertas()
    elif etapa == "4":
        verificar_colunas_inep()
    elif etapa == "5":
        tratar_nans_cine_inscritos()
    elif etapa == "6":
        tratar_nans_cine_ofertas()
    elif etapa == "7":
        processar_modalidades_e_peneira()
    elif etapa == "all":
        transform_inep()
        transform_inscritos()
        transform_ofertas()
        verificar_colunas_inep()
        tratar_nans_cine_inscritos()
        tratar_nans_cine_ofertas()
        processar_modalidades_e_peneira()

elif comando == "load":

    load_inscritos()
    load_ofertas()
    auditoria_inscritos_carregados()
    auditoria_ofertas_carregadas()
    exportar_para_sqlite()
# Out:
# ==================================================
# Iniciando Transformação: INEP (Dataset Mestre de Cursos)
# ==================================================
# Buscando arquivos na Staging: /home/eq_lucas/Documents/projetos/kdd-pipeline-microdata-fies/data/02_staging/microdata inep
#   [*] Lendo e filtrando: MICRODADOS_CADASTRO_CURSOS_2016.csv
#   [*] Lendo e filtrando: MICRODADOS_CADASTRO_CURSOS_2017.csv
#   [*] Lendo e filtrando: MICRODADOS_CADASTRO_CURSOS_2018.csv
#   [*] Lendo e filtrando: MICRODADOS_CADASTRO_CURSOS_2019.csv
#   [*] Lendo e filtrando: MICRODADOS_CADASTRO_CURSOS_2020.csv
#   [*] Lendo e filtrando: MICRODADOS_CADASTRO_CURSOS_2021.csv
#   [*] Lendo e filtrando: MICRODADOS_CADASTRO_CURSOS_2022.csv
#   [*] Lendo e filtrando: MICRODADOS_CADASTRO_CURSOS_2023.csv
#   [*] Lendo e filtrando: MICRODADOS_CADASTRO_CURSOS_2024.csv
#
# [*] Empilhando os Censos num único Dataset Mestre...
#
# --- Processo Concluído! ---
# Total de 9 arquivos unificados do INEP.
# Dataset Mestre salvo em: /home/eq_lucas/Documents/projetos/kdd-pipeline-microdata-fies/data/03_transform/inep/df_mestre_cadastro_cursos_2016_2024.parquet
# Total de linhas na tabela dimensional: 3403150
