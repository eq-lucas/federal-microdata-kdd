# %%
import sys
import pandas as pd
from src.staging import staging_fies, staging_inep
from src.transform_layer_1 import transform_inscritos, transform_ofertas, transform_inep, verificar_colunas_inep
from src.transform_layer_2 import tratar_nans_cine_inscritos, tratar_nans_cine_ofertas
from src.trasnform_layer_3 import processar_modalidades_e_peneira
from src.load import load_inscritos,load_ofertas,auditoria_inscritos_carregados,auditoria_ofertas_carregadas,exportar_para_sqlite
    
comando = 'transform'
etapa = '4'

# --- CAMADA: STAGING ---
if comando == "staging":
    staging_fies()
    staging_inep()

# --- CAMADA: TRANSFORM ---
elif comando == "transform":

    if etapa == "1":
        transform_inep()
    elif etapa == "2":
        transform_inscritos()
    elif etapa == "3":
        transform_ofertas()
    elif etapa == "4":
        verificar_colunas_inep()
    elif etapa == "5":
        tratar_nans_cine_inscritos()
    elif etapa == "6":
        tratar_nans_cine_ofertas()
    elif etapa == "7":
        processar_modalidades_e_peneira()
    elif etapa == "all":
        transform_inep()
        transform_inscritos()
        transform_ofertas()
        verificar_colunas_inep()
        tratar_nans_cine_inscritos()
        tratar_nans_cine_ofertas()
        processar_modalidades_e_peneira()

elif comando == "load":

    load_inscritos()
    load_ofertas()
    auditoria_inscritos_carregados()
    auditoria_ofertas_carregadas()
    exportar_para_sqlite()
# Out:
# ==================================================
# 🕵️ AUDITORIA DE METADADOS: INEP (Censo Superior)
# ==================================================
# Buscando arquivos na Staging: /home/eq_lucas/Documents/projetos/kdd-pipeline-microdata-fies/data/02_staging/microdata inep
#
# --- Processando 2016 ---
#   > OK: Arquivo 2016 lido. Total: 200 colunas.
# --- Processando 2017 ---
#   > OK: Arquivo 2017 lido. Total: 200 colunas.
# --- Processando 2018 ---
#   > OK: Arquivo 2018 lido. Total: 200 colunas.
# --- Processando 2019 ---
#   > OK: Arquivo 2019 lido. Total: 200 colunas.
# --- Processando 2020 ---
#   > OK: Arquivo 2020 lido. Total: 200 colunas.
# --- Processando 2021 ---
#   > OK: Arquivo 2021 lido. Total: 200 colunas.
# --- Processando 2022 ---
#   > OK: Arquivo 2022 lido. Total: 200 colunas.
# --- Processando 2023 ---
#   > OK: Arquivo 2023 lido. Total: 202 colunas.
# --- Processando 2024 ---
#   > OK: Arquivo 2024 lido. Total: 223 colunas.
#
# --- Leitura de Cabeçalhos Concluída ---
#
# --- 🔍 Comparando Esquemas de Colunas ---
# Referência: 2016 (200 colunas).
#
# Comparando 2016 vs 2017:
#   ✅ Os conjuntos de colunas são EXATAMENTE idênticos.
#
# Comparando 2016 vs 2018:
#   ✅ Os conjuntos de colunas são EXATAMENTE idênticos.
#
# Comparando 2016 vs 2019:
#   ✅ Os conjuntos de colunas são EXATAMENTE idênticos.
#
# Comparando 2016 vs 2020:
#   [!] Colunas em 2016 que NÃO estão em 2020: {'CO_CINE_ROTULO'}
#   [!] Colunas em 2020 que NÃO estão em 2016: {'CO_CINE_ROTULO2'}
#
# Comparando 2016 vs 2021:
#   ✅ Os conjuntos de colunas são EXATAMENTE idênticos.
#
# Comparando 2016 vs 2022:
#   ✅ Os conjuntos de colunas são EXATAMENTE idênticos.
#
# Comparando 2016 vs 2023:
#   [!] Colunas em 2023 que NÃO estão em 2016: {'IN_COMUNITARIA', 'IN_CONFESSIONAL'}
#
# Comparando 2016 vs 2024:
#   [!] Colunas em 2016 que NÃO estão em 2024: {'QT_ING_RVETNICO', 'QT_MAT_RVETNICO', 'QT_CONC_RVETNICO'}
#   [!] Colunas em 2024 que NÃO estão em 2016: {'QT_MAT_RVMEDAL', 'QT_ING_RVPOVT', 'QT_ING_RVINTERN', 'QT_MAT_RVQUILO', 'QT_CONC_RVQUILO', 'QT_CONC_RVINTERN', 'QT_CONC_RVREFU', 'IN_CONFESSIONAL', 'QT_CONC_RVIDOSO', 'QT_ING_RVMEDAL', 'QT_MAT_RVPPI', 'QT_ING_RVQUILO', 'QT_CONC_RVTRANS', 'QT_ING_RVREFU', 'QT_ING_RVTRANS', 'IN_COMUNITARIA', 'QT_ING_RVIDOSO', 'QT_MAT_RVPOVT', 'QT_ING_RVPPI', 'QT_MAT_RVREFU', 'QT_CONC_RVPPI', 'QT_CONC_RVMEDAL', 'QT_MAT_RVIDOSO', 'QT_MAT_RVTRANS', 'QT_CONC_RVPOVT', 'QT_MAT_RVINTERN'}
#
#
# --- 📜 Listagem Bruta das Colunas ---
#
# ====================
# COLUNAS 2016
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2017
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2018
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2019
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2020
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO2
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2021
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2022
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2023
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_COMUNITARIA
# IN_CONFESSIONAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2024
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_COMUNITARIA
# IN_CONFESSIONAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVIDOSO
# QT_CONC_RVINTERN
# QT_CONC_RVMEDAL
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVPOVT
# QT_CONC_RVPPI
# QT_CONC_RVQUILO
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVREFU
# QT_CONC_RVSOCIAL_RF
# QT_CONC_RVTRANS
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVIDOSO
# QT_ING_RVINTERN
# QT_ING_RVMEDAL
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVPOVT
# QT_ING_RVPPI
# QT_ING_RVQUILO
# QT_ING_RVREDEPUBLICA
# QT_ING_RVREFU
# QT_ING_RVSOCIAL_RF
# QT_ING_RVTRANS
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVIDOSO
# QT_MAT_RVINTERN
# QT_MAT_RVMEDAL
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVPOVT
# QT_MAT_RVPPI
# QT_MAT_RVQUILO
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVREFU
# QT_MAT_RVSOCIAL_RF
# QT_MAT_RVTRANS
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ================================================================================
# 📊 AUDITORIA CINE E NaNs: FIES INSCRITOS
# ================================================================================
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2019 | Semestre 1 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             287817
# Negócios, administração e direito                             186725
# Engenharia, produção e construção                              70080
# Ciências sociais, comunicação e informação                     47449
# Educação                                                       27659
# Agricultura, silvicultura, pesca e veterinária                 23447
# Computação e Tecnologias da Informação e Comunicação (TIC)     18650
# None                                                           14945
# Serviços                                                       10610
# Artes e humanidades                                             6682
# Ciências naturais, matemática e estatística                     2667
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de inscritos (linhas): 696731
#   Total de NaNs (cursos não encontrados): 14945
#   Percentual de NaNs: 2.15%
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2019 | Semestre 2 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             122825
# Negócios, administração e direito                              72308
# Engenharia, produção e construção                              24932
# Ciências sociais, comunicação e informação                     19077
# Agricultura, silvicultura, pesca e veterinária                  9446
# Educação                                                        7479
# Computação e Tecnologias da Informação e Comunicação (TIC)      6479
# Serviços                                                        3891
# Artes e humanidades                                             2151
# None                                                            2010
# Ciências naturais, matemática e estatística                      718
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de inscritos (linhas): 271316
#   Total de NaNs (cursos não encontrados): 2010
#   Percentual de NaNs: 0.74%
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2020 | Semestre 1 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             250079
# Negócios, administração e direito                             131619
# Engenharia, produção e construção                              44173
# Ciências sociais, comunicação e informação                     41805
# Agricultura, silvicultura, pesca e veterinária                 21071
# Educação                                                       16921
# Computação e Tecnologias da Informação e Comunicação (TIC)     14560
# Serviços                                                        8052
# Artes e humanidades                                             4676
# None                                                            4595
# Ciências naturais, matemática e estatística                     1822
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de inscritos (linhas): 539373
#   Total de NaNs (cursos não encontrados): 4595
#   Percentual de NaNs: 0.85%
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2020 | Semestre 2 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             110763
# Negócios, administração e direito                              47002
# Ciências sociais, comunicação e informação                     15206
# Engenharia, produção e construção                              13832
# Agricultura, silvicultura, pesca e veterinária                  8254
# Educação                                                        4399
# Computação e Tecnologias da Informação e Comunicação (TIC)      4006
# Serviços                                                        2567
# Artes e humanidades                                             1542
# None                                                            1452
# Ciências naturais, matemática e estatística                      479
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de inscritos (linhas): 209502
#   Total de NaNs (cursos não encontrados): 1452
#   Percentual de NaNs: 0.69%
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2021 | Semestre 1 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             139665
# Negócios, administração e direito                              51290
# Ciências sociais, comunicação e informação                     18038
# Engenharia, produção e construção                              15020
# Agricultura, silvicultura, pesca e veterinária                 10057
# Computação e Tecnologias da Informação e Comunicação (TIC)      5192
# Educação                                                        5098
# Serviços                                                        2727
# Artes e humanidades                                             1944
# None                                                            1339
# Ciências naturais, matemática e estatística                      648
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de inscritos (linhas): 251018
#   Total de NaNs (cursos não encontrados): 1339
#   Percentual de NaNs: 0.53%
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2021 | Semestre 2 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             133054
# Negócios, administração e direito                              44311
# Ciências sociais, comunicação e informação                     16086
# Engenharia, produção e construção                              12927
# Agricultura, silvicultura, pesca e veterinária                  9829
# Computação e Tecnologias da Informação e Comunicação (TIC)      4526
# Educação                                                        3535
# Serviços                                                        1968
# Artes e humanidades                                             1538
# None                                                            1020
# Ciências naturais, matemática e estatística                      500
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de inscritos (linhas): 229294
#   Total de NaNs (cursos não encontrados): 1020
#   Percentual de NaNs: 0.44%
#
# ================================================================================
# --- RESUMO GERAL (TODOS OS ANOS) ---
# Total Geral de Inscritos: 2197234
# Total Geral de NaNs: 25361 (1.15%)
# ================================================================================
#
#
# ================================================================================
# 📊 AUDITORIA CINE E NaNs: FIES OFERTAS
# ================================================================================
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2019.0 | Semestre 1.0 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             7415
# Saúde e bem-estar                                             6006
# Engenharia, produção e construção                             4580
# None                                                          2436
# Educação                                                      2296
# Computação e Tecnologias da Informação e Comunicação (TIC)    1540
# Ciências sociais, comunicação e informação                    1457
# Serviços                                                       948
# Artes e humanidades                                            746
# Agricultura, silvicultura, pesca e veterinária                 546
# Ciências naturais, matemática e estatística                    187
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de ofertas (linhas): 28157
#   Total de NaNs (cursos não encontrados): 2436
#   Percentual de NaNs: 8.65%
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2019.0 | Semestre 2.0 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             6192
# Saúde e bem-estar                                             5253
# Engenharia, produção e construção                             3858
# Educação                                                      1611
# Ciências sociais, comunicação e informação                    1282
# Computação e Tecnologias da Informação e Comunicação (TIC)    1133
# None                                                           835
# Serviços                                                       697
# Artes e humanidades                                            599
# Agricultura, silvicultura, pesca e veterinária                 461
# Ciências naturais, matemática e estatística                    138
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de ofertas (linhas): 22059
#   Total de NaNs (cursos não encontrados): 835
#   Percentual de NaNs: 3.79%
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2020.0 | Semestre 1.0 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             6730
# Saúde e bem-estar                                             5972
# Engenharia, produção e construção                             4040
# Educação                                                      1821
# Ciências sociais, comunicação e informação                    1561
# Computação e Tecnologias da Informação e Comunicação (TIC)    1331
# None                                                           887
# Serviços                                                       859
# Artes e humanidades                                            676
# Agricultura, silvicultura, pesca e veterinária                 618
# Ciências naturais, matemática e estatística                    172
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de ofertas (linhas): 24667
#   Total de NaNs (cursos não encontrados): 887
#   Percentual de NaNs: 3.60%
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2020.0 | Semestre 2.0 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             6285
# Saúde e bem-estar                                             5627
# Engenharia, produção e construção                             3335
# Ciências sociais, comunicação e informação                    1479
# Educação                                                      1362
# Computação e Tecnologias da Informação e Comunicação (TIC)    1232
# Serviços                                                       720
# None                                                           627
# Artes e humanidades                                            595
# Agricultura, silvicultura, pesca e veterinária                 569
# Ciências naturais, matemática e estatística                    125
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de ofertas (linhas): 21956
#   Total de NaNs (cursos não encontrados): 627
#   Percentual de NaNs: 2.86%
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2021.0 | Semestre 1.0 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             6679
# Saúde e bem-estar                                             5942
# Engenharia, produção e construção                             3463
# Ciências sociais, comunicação e informação                    1655
# Educação                                                      1525
# Computação e Tecnologias da Informação e Comunicação (TIC)    1331
# Serviços                                                       732
# Agricultura, silvicultura, pesca e veterinária                 671
# None                                                           666
# Artes e humanidades                                            643
# Ciências naturais, matemática e estatística                    156
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de ofertas (linhas): 23463
#   Total de NaNs (cursos não encontrados): 666
#   Percentual de NaNs: 2.84%
#
# --------------------------------------------------------------------------------
# --- Iniciando Análise do Período: Ano 2021.0 | Semestre 2.0 ---
# --------------------------------------------------------------------------------
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             6322
# Saúde e bem-estar                                             6100
# Engenharia, produção e construção                             3498
# Ciências sociais, comunicação e informação                    1620
# Educação                                                      1578
# Computação e Tecnologias da Informação e Comunicação (TIC)    1301
# Serviços                                                       746
# Artes e humanidades                                            699
# None                                                           668
# Agricultura, silvicultura, pesca e veterinária                 650
# Ciências naturais, matemática e estatística                    138
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este período) ---
#   Total de ofertas (linhas): 23320
#   Total de NaNs (cursos não encontrados): 668
#   Percentual de NaNs: 2.86%
#
# ================================================================================
# --- RESUMO GERAL (TODOS OS ANOS) ---
# Total Geral de Ofertas: 143623
# Total Geral de NaNs: 6120 (4.26%)
# ================================================================================
