# %%
import sys
import pandas as pd
from src.staging import staging_fies, staging_inep
from src.transform_layer_1 import transform_inscritos, transform_ofertas, transform_inep, verificar_colunas_inep
from src.transform_layer_2 import tratar_nans_cine_inscritos, tratar_nans_cine_ofertas
from src.trasnform_layer_3 import processar_modalidades_e_peneira
from src.load import load_inscritos,load_ofertas,auditoria_inscritos_carregados,auditoria_ofertas_carregadas,exportar_para_sqlite
    
comando = 'staging'
etapa = '7'

# --- CAMADA: STAGING ---
if comando == "staging":
    staging_fies()
    staging_inep()

# --- CAMADA: TRANSFORM ---
elif comando == "transform":

    if etapa == "1":
        transform_inep()
    elif etapa == "2":
        transform_inscritos()
    elif etapa == "3":
        transform_ofertas()
    elif etapa == "4":
        verificar_colunas_inep()
    elif etapa == "5":
        tratar_nans_cine_inscritos()
    elif etapa == "6":
        tratar_nans_cine_ofertas()
    elif etapa == "7":
        processar_modalidades_e_peneira()
    elif etapa == "all":
        transform_inep()
        transform_inscritos()
        transform_ofertas()
        verificar_colunas_inep()
        tratar_nans_cine_inscritos()
        tratar_nans_cine_ofertas()
        processar_modalidades_e_peneira()

elif comando == "load":

    load_inscritos()
    load_ofertas()
    auditoria_inscritos_carregados()
    auditoria_ofertas_carregadas()
    exportar_para_sqlite()
# Out:
# Buscando arquivos originais do INEP em: /home/eq_lucas/Documents/projetos/kdd-pipeline-microdata-fies/data/01_raw/microdata fies
#
# [*] Processando: 'relatorio_inscricao_dados_abertos_fies_12019.csv'
#     -> Salvando como: 'fies_1_inscricao_2019_sem_duplicata.csv'
# [*] Processando: 'relatorio_inscricao_dados_abertos_fies_22019.csv'
#     -> Salvando como: 'fies_2_inscricao_2019_sem_duplicata.csv'
# [*] Processando: 'relatorio_dados_abertos_oferta_12019_18102021.csv'
#     -> Salvando como: 'fies_1_ofertas_2019_sem_duplicata.csv'
# [*] Processando: 'relatorio_dados_abertos_oferta_22019_18102021.csv'
#     -> Salvando como: 'fies_2_ofertas_2019_sem_duplicata.csv'
# [*] Processando: 'relatorio_inscricao_dados_abertos_fies_12020.csv'
#     -> Salvando como: 'fies_1_inscricao_2020_sem_duplicata.csv'
# [*] Processando: 'relatorio_inscricao_dados_abertos_fies_22020.csv'
#     -> Salvando como: 'fies_2_inscricao_2020_sem_duplicata.csv'
# [*] Processando: 'relatorio_dados_abertos_oferta_12020_18102021.csv'
#     -> Salvando como: 'fies_1_ofertas_2020_sem_duplicata.csv'
# [*] Processando: 'relatorio_dados_abertos_oferta_22020_18102021.csv'
#     -> Salvando como: 'fies_2_ofertas_2020_sem_duplicata.csv'
# [*] Processando: 'relatorio_inscricao_dados_abertos_fies_12021.csv'
#     -> Salvando como: 'fies_1_inscricao_2021_sem_duplicata.csv'
# [*] Processando: 'relatorio_inscricao_dados_abertos_fies_22021.csv'
#     -> Salvando como: 'fies_2_inscricao_2021_sem_duplicata.csv'
# [*] Processando: 'relatorio_dados_abertos_oferta_12021_18102021.csv'
#     -> Salvando como: 'fies_1_ofertas_2021_sem_duplicata.csv'
# [*] Processando: 'relatorio_dados_abertos_oferta_22021_18102021.csv'
#     -> Salvando como: 'fies_2_ofertas_2021_sem_duplicata.csv'
# [AVISO] 'relatorio_dados_abertos_oferta_12022_15072022.csv' não encontrado na pasta 01_raw. Pulando.
# [*] Processando: 'relatorio_resultado_fies_12021.csv'
#     -> Salvando como: 'resultado_fies_2020_1.csv'
# Limpeza Concluída! 13 de 14 arquivos salvos em 02_staging.
#
# ==========================================================================================
# 🧹 INICIANDO LIMPEZA MASSIVA E UNIVERSAL (STAGING) - 140+ COLUNAS
# ==========================================================================================
# [*] Aplicando higienização profunda em: fies_1_ofertas_2021_sem_duplicata.csv
#    ✅ [OK] 58 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_2_inscricao_2020_sem_duplicata.csv
#    ✅ [OK] 59 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_2_ofertas_2019_sem_duplicata.csv
#    ✅ [OK] 65 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_1_ofertas_2020_sem_duplicata.csv
#    ✅ [OK] 65 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_1_ofertas_2019_sem_duplicata.csv
#    ✅ [OK] 65 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_2_ofertas_2021_sem_duplicata.csv
#    ✅ [OK] 58 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_1_inscricao_2020_sem_duplicata.csv
#    ✅ [OK] 59 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_2_inscricao_2019_sem_duplicata.csv
#    ✅ [OK] 59 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_2_inscricao_2021_sem_duplicata.csv
#    ✅ [OK] 59 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_1_inscricao_2021_sem_duplicata.csv
#    ✅ [OK] 59 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_2_ofertas_2020_sem_duplicata.csv
#    ✅ [OK] 58 colunas perfeitamente formatadas!
# [*] Aplicando higienização profunda em: fies_1_inscricao_2019_sem_duplicata.csv
#    ✅ [OK] 59 colunas perfeitamente formatadas!
#
# ==========================================================================================
# 🏁 LIMPEZA AVANÇADA CONCLUÍDA! O STAGING AGORA É UM ESPELHO PERFEITO.
# ==========================================================================================
#
#
# --- 1. INICIANDO CÓPIA E RENAME (Usando os.listdir) ---
#
# --- Processando ano: 2016 ---
#   AVISO: Nenhuma pasta encontrada para o ano 2016. Pulando.
#
# --- Processando ano: 2017 ---
#   AVISO: Nenhuma pasta encontrada para o ano 2017. Pulando.
#
# --- Processando ano: 2018 ---
#   AVISO: Nenhuma pasta encontrada para o ano 2018. Pulando.
#
# --- Processando ano: 2019 ---
#   AVISO: Nenhuma pasta encontrada para o ano 2019. Pulando.
#
# --- Processando ano: 2020 ---
#   AVISO: Nenhuma pasta encontrada para o ano 2020. Pulando.
#
# --- Processando ano: 2021 ---
#   AVISO: Nenhuma pasta encontrada para o ano 2021. Pulando.
#
# --- Processando ano: 2022 ---
#   AVISO: Nenhuma pasta encontrada para o ano 2022. Pulando.
#
# --- Processando ano: 2023 ---
#   AVISO: Nenhuma pasta encontrada para o ano 2023. Pulando.
#
# --- Processando ano: 2024 ---
#   AVISO: Nenhuma pasta encontrada para o ano 2024. Pulando.
#
# --- PROCESSO COMPLETO CONCLUÍDO ---
# Ficheiros copiados e renomeados: 0
# Total de erros encontrados: 0
