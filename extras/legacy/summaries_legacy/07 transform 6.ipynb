# %%
import sys
import pandas as pd
from src.staging import staging_fies, staging_inep
from src.transform_layer_1 import transform_inscritos, transform_ofertas, transform_inep, verificar_colunas_inep
from src.transform_layer_2 import tratar_nans_cine_inscritos, tratar_nans_cine_ofertas
from src.trasnform_layer_3 import processar_modalidades_e_peneira
from src.load import load_inscritos,load_ofertas,auditoria_inscritos_carregados,auditoria_ofertas_carregadas,exportar_para_sqlite
    
comando = 'transform'
etapa = '6'

# --- CAMADA: STAGING ---
if comando == "staging":
    staging_fies()
    staging_inep()

# --- CAMADA: TRANSFORM ---
elif comando == "transform":

    if etapa == "1":
        transform_inep()
    elif etapa == "2":
        transform_inscritos()
    elif etapa == "3":
        transform_ofertas()
    elif etapa == "4":
        verificar_colunas_inep()
    elif etapa == "5":
        tratar_nans_cine_inscritos()
    elif etapa == "6":
        tratar_nans_cine_ofertas()
    elif etapa == "7":
        processar_modalidades_e_peneira()
    elif etapa == "all":
        transform_inep()
        transform_inscritos()
        transform_ofertas()
        verificar_colunas_inep()
        tratar_nans_cine_inscritos()
        tratar_nans_cine_ofertas()
        processar_modalidades_e_peneira()

elif comando == "load":

    load_inscritos()
    load_ofertas()
    auditoria_inscritos_carregados()
    auditoria_ofertas_carregadas()
    exportar_para_sqlite()
# Out:
# ============================================================
# 🛠️ INICIANDO LAYER 2: TRATAMENTO DE NaNs CINE - OFERTAS
# ============================================================
# [*] Lendo arquivo unificado de ofertas: fies_ofertas_unificado.parquet...
#
# [*] ETAPA A: Extraindo dicionário de cursos válidos (Ofertas)...
#   -> Salvo: dataset_auxiliar_curso_area_ofertas.csv (377 cursos únicos)
#
# [*] ETAPA B: Analisando NaNs em Ofertas...
#   -> Total de NaNs encontrados ANTES da correção: 6120
#   -> Lista de cursos problemáticos salva em: analise_nomes_nan_ofertas.csv
#
# [*] ETAPA C: Aplicando correções manuais (Vetorizado)...
#   -> Total de NaNs DEPOIS da correção: 6
#   -> Total de NaNs resolvidos: 6114
#
# [*] ETAPA D: Salvando o Dataset de Ofertas Corrigido...
#   -> Arquivo final salvo com sucesso em: fies_ofertas_unificado_corrigido.parquet
#
# ============================================================
# ✅ LAYER 2 CONCLUÍDA (OFERTAS)
# ============================================================
#
# ================================================================================
# 🎯 AUDITORIA PÓS-CORREÇÃO (LAYER 2): FIES OFERTAS
# ================================================================================
#
# 📊 Contagem Global de Valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             41022
# Saúde e bem-estar                                             35923
# Engenharia, produção e construção                             24154
# Educação                                                      10724
# Ciências sociais, comunicação e informação                     9342
# Computação e Tecnologias da Informação e Comunicação (TIC)     8347
# Serviços                                                       5169
# Artes e humanidades                                            4270
# Agricultura, silvicultura, pesca e veterinária                 3630
# Ciências naturais, matemática e estatística                    1036
# None                                                              6
# Name: count, dtype: int64
#
# ----------------------------------------
# ✅ RESUMO DE INTEGRIDADE: OFERTAS
# ----------------------------------------
# Total de Ofertas Processadas   : 143623
# Total de NaNs (Não Mapeados)   : 6
# Taxa de Perda Residual         : 0.00%
# ================================================================================
